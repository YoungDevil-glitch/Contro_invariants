# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
def eulerexplicite(t_0, t_f: float, D: list, f, u , x_0, n =None, h=None):
    """Implementing euler method on a pertubation scheme. Work well when the pertubation set is finite"""
    assert n is not None or h is not None, "precise a step or a number of steps"
    if n is not None: 
        h = (t_f - t_0)/n
    else: 
        n = int((t_f - t_0)/n)+1
    Timestep = [t_0 + i*h for i in range(n+1)]
    Timestep[n] = t_f
    Reach = [[x_0]]
    for i in range(n): 
        h = Timestep[i+1] - Timestep[i]
        new = [x+ h*f(x,u(Timestep[i]), d) for x in Reach[i] for d in D] 
        
        Reach.append(new)
    return Reach, Timestep

# %%
N = [5, 10, 20, 25]
figure, ax= plt.subplots(2,2,figsize = (6,6))
h=0
j=0
for n in N: 
    Reach, Timestep = eulerexplicite(0, 1,np.linspace(0,0.2, 2) , lambda x,u,d: x+u+d, lambda t: np.exp(t)/(1+np.exp(t)) , x_0 =0, n =n, h=None)
    for i in range(n): 
        m = len(Reach[i])
        ax[h][j].scatter([Timestep[i]]*m,Reach[i])
    h+=int(j==1)
    j = (j+1)%2
plt.show()

# %% [markdown]
# # CDSM SYSTEM
# We can simplfy our analysis to a discrete set of x and u and d.

# %%
def sampling_increasing_sequence(N): 
    L= [0]
    for i in range(N-1): 
        L.append(L[-1]+np.random.lognormal())
    return L
def sampling_function(N, D): 
    """The goal is to randomly generates a function from T to the sets.
    We will be doing affine approximation of this function"""
    T = sampling_increasing_sequence(N)
    S = np.random.choice(D, size =N)
    return T,S
def piecewise_affine(t,T,S):
    a = 0 
    b = len(T)-1
    if  (t >= T[-1]): 
        return S[-1]
    while (b-a)>1 :
        m = int((a+b)//2)
        if t >= T[m]:
            a = m
        else: 
            b=m
    h = S[a] + (S[b] - S[a])*(t-T[a])/(T[b] - T[a])
    return h
def sampling_stepfunction(N, D): 
    """The goal is to randomly generates a function from T to the sets.
    We will be doing affine approximation of this function"""
    S = np.random.choice(D, size =N)
    return S
def step_function(t,h,S): 
    m = len(T)
    n = int(t/h)
    if n >= m: 
        return S[-1]
    return S[n]

# %%
T,S = sampling_function(6, np.linspace(0,0.2, 10).reshape((5,2)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20756\1585876631.py in <module>
# ----> 1 T,S = sampling_function(6, np.linspace(0,0.2, 10).reshape((5,2)))
#
# ~\AppData\Local\Temp\ipykernel_20756\583732359.py in sampling_function(N, D)
#       8     We will be doing affine approximation of this function"""
#       9     T = sampling_increasing_sequence(N)
# ---> 10     S = np.random.choice(D, size =N)
#      11     return T,S
#      12 def piecewise_affine(t,T,S):
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be 1-dimensional

# %%
x= np.linspace(0,25,100)
y = [piecewise_affine(t,T,S) for t in x]
fig = plt.figure()
plt.plot(T,S,"-g", label="line")
plt.plot(x,y,"b", label="line_2")

# %%
S= sampling_stepfunction(10, np.linspace(0,0.2, 5))
x= np.linspace(0,25,100)
h = 1 
y = [step_function(t,h,S) for t in x]
fig = plt.figure()

plt.plot(x,y,"b", label="line_2")

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
